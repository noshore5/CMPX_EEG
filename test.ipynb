# %%
from utils.coherence_utils import coherence, transform

# %%
import fcwt
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio

# %%
# Generate two random signals
np.random.seed(42)  # For reproducibility
signal1 = np.random.randn(1000)
signal2 = np.random.randn(1000)
# Test the coherence function)

# Test the transform function
t1, freqs = transform(signal1,1,100,50,100)
t2,_ = transform(signal2,1,100,50,100)

coh = coherence(t1, t2, freqs)
plt.imshow(abs(t1))

# %%
import matplotlib.pyplot as plt
from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize

import mne
from mne.datasets import sample

print(__doc__)

data_path = sample.data_path()
subjects_dir = data_path / "subjects"
sample_dir = data_path / "MEG" / "sample"
# Out:
# Automatically created module for IPython interactive environment
# Using default location ~/mne_data for sample...
# Creating /Users/noahshore/mne_data
# ...
# /Users/noahshore/Documents/CoherIQs/CMPX_EEG/CMPX/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# 100%|█████████████████████████████████████| 1.65G/1.65G [00:00<00:00, 5.01TB/s]
# Untarring contents of '/Users/noahshore/mne_data/MNE-sample-data-processed.tar.gz' to '/Users/noahshore/mne_data'
# Attempting to create new mne-python configuration file:
# /Users/noahshore/.mne/mne-python.json
# Download complete in 01m21s (1576.2 MB)

# %%
# test_fastapi_import.py
from fastapi import FileResponse
print("FileResponse imported successfully")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 # test_fastapi_import.py
# ----> 2 from fastapi import FileResponse
#       3 print("FileResponse imported successfully")
#
# ImportError: cannot import name 'FileResponse' from 'fastapi' (/Users/noahshore/Documents/CoherIQs/CMPX_EEG/CMPX/lib/python3.9/site-packages/fastapi/__init__.py)
